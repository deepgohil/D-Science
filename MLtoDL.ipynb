# %% [markdown]
# <a href="https://colab.research.google.com/github/deepgohil/D-Science/blob/main/MLtoDL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6cc71d91-994e-4f3c-b8e4-200a0b378ef4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6cc71d91-994e-4f3c-b8e4-200a0b378ef4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes.csv

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = df.iloc[:, :8]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=df.iloc[:,8]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ANN APPLY

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
from tensorflow.keras import initializers

# %%
model = Sequential()
model.add(Dense(units=11, activation='relu'))
model.add(Dense(units=100, activation='tanh',kernel_initializer=initializers.HeUniform()))
model.add(Dense(units=50, activation='relu',kernel_initializer=initializers.GlorotUniform()))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(optimizer='AdaDelta',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_history=model.fit(X_train,y_train,batch_size=32,epochs=50,validation_split=0.20)
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 19ms/step - loss: 0.7237 - accuracy: 0.4842 - val_loss: 0.7008 - val_accuracy: 0.5340
# Epoch 2/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7232 - accuracy: 0.4842 - val_loss: 0.7004 - val_accuracy: 0.5340
# Epoch 3/50
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7226 - accuracy: 0.4842 - val_loss: 0.6999 - val_accuracy: 0.5340
# Epoch 4/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7221 - accuracy: 0.4866 - val_loss: 0.6995 - val_accuracy: 0.5340
# Epoch 5/50
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7215 - accuracy: 0.4866 - val_loss: 0.6990 - val_accuracy: 0.5437
# Epoch 6/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7210 - accuracy: 0.4891 - val_loss: 0.6986 - val_accuracy: 0.5437
# Epoch 7/50
# ...

# %%
model = Sequential()
model.add(Dense(units=11, activation='relu'))
model.add(Dense(units=100, activation='selu',kernel_initializer=initializers.HeUniform()))
model.add(Dense(units=50, activation='tanh',kernel_initializer=initializers.GlorotUniform()))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(optimizer='AdaDelta',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_history=model.fit(X_train,y_train,batch_size=32,epochs=250,validation_split=0.20)
# Out:
# Epoch 1/250
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6185 - accuracy: 0.6934 - val_loss: 0.6687 - val_accuracy: 0.5728
# Epoch 2/250
# 13/13 [==============================] - 0s 11ms/step - loss: 0.6181 - accuracy: 0.6934 - val_loss: 0.6684 - val_accuracy: 0.5728
# Epoch 3/250
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6178 - accuracy: 0.6934 - val_loss: 0.6682 - val_accuracy: 0.5728
# Epoch 4/250
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6174 - accuracy: 0.6934 - val_loss: 0.6679 - val_accuracy: 0.5728
# Epoch 5/250
# 13/13 [==============================] - 0s 11ms/step - loss: 0.6170 - accuracy: 0.6934 - val_loss: 0.6676 - val_accuracy: 0.5728
# Epoch 6/250
# 13/13 [==============================] - 0s 11ms/step - loss: 0.6167 - accuracy: 0.6934 - val_loss: 0.6673 - val_accuracy: 0.5728
# Epoch 7/250
# ...

# %%
print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
cm
# Out:
# array([[159,   9],
#        [ 59,  27]])

# %%
score
# Out:
# 0.7322834645669292

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-d971413b0e24> in <module>()
# ----> 1 print(accuracy_score(y, y_pred))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# ...
